# %%
# Import necessary packages
import cv2

# Import image
image = cv2.imread("car_image.jpg")

# Run HOG algorithm on image to output feature vector.
hog = cv2.HOGDescriptor()
feature_vector = hog.compute(image)
list(feature_vector)
# Out:
# [0.1506354,
#  0.0701376,
#  0.08607551,
#  0.12188191,
#  0.14875945,
#  0.04630348,
#  0.076591805,
#  0.03787035,
#  0.13811351,
#  0.03879284,
#  0.06965516,
#  0.16817085,
#  0.4327458,
#  0.24484575,
#  0.112716414,
#  0.045209013,
#  0.010008043,
#  0.027172014,
#  0.3123933,
#  0.12855005,
#  0.12872355,
#  0.096028626,
#  0.058248427,
#  0.017555378,
#  0.021159865,
#  0.015190233,
#  0.255832,
#  0.09985198,
#  0.12746821,
#  0.3580682,
#  0.44853196,
#  0.14845584,
#  0.052693516,
#  0.01893649,
#  0.004102207,
#  0.083744906,
#  0.015038197,
#  0.074938245,
#  0.17607628,
#  0.44529963,
#  0.1616536,
#  0.05933166,
#  0.012565664,
#  0.0077521633,
#  0.0061318655,
#  0.049954083,
#  0.21746284,
#  0.26806322,
#  0.22185624,
#  0.069537856,
#  0.0075621274,
#  0.0037808386,
#  0.0037444918,
#  0.020077957,
#  0.024108041,
#  0.09595681,
#  0.29666734,
#  0.45131096,
#  0.10422725,
#  0.026631948,
#  0.013557063,
#  0.008477875,
#  0.017418446,
#  0.045453504,
# ...
