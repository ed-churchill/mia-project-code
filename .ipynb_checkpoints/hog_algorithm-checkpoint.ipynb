# %%
# Import necessary packages
import cv2

# Import image
image = cv2.imread("car_image.jpg")

# Run HOG algorithm on image to output feature vector.
hog = cv2.HOGDescriptor()
feature_vector = hog.compute(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7024/1420931229.py in <module>
#       7 # Run HOG algorithm on image to output feature vector.
#       8 hog = cv2.HOGDescriptor()
# ----> 9 feature_vector = hog.compite(image)
#
# AttributeError: 'cv2.HOGDescriptor' object has no attribute 'compite'
